# %%
import pandas as pd

# %%
test=pd.read_csv("/content/DEEP LEARNING/test.csv")

# %%
train=pd.read_csv("/content/DEEP LEARNING/train.csv")

# %%
train.isna().sum()
# Out:
# id              0
# brand           0
# model           0
# model_year      0
# milage          0
# fuel_type       0
# engine          0
# transmission    0
# ext_col         0
# int_col         0
# accident        0
# clean_title     0
# price           0
# dtype: int64

# %%
for col in train:
  print(f"{col}:{train[col].unique()}")
  print(len(train[col].unique()))
# Out:
# id:[    0     1     2 ... 54270 54271 54272]
# 54273
# brand:['Ford' 'BMW' 'Jaguar' 'Pontiac' 'Acura' 'Audi' 'GMC' 'Maserati'
#  'Chevrolet' 'Porsche' 'Mercedes-Benz' 'Tesla' 'Lexus' 'Kia' 'Lincoln'
#  'Dodge' 'Volkswagen' 'Land' 'Cadillac' 'Mazda' 'RAM' 'Subaru' 'Hyundai'
#  'MINI' 'Jeep' 'Honda' 'Hummer' 'Nissan' 'Toyota' 'Volvo' 'Genesis'
#  'Mitsubishi' 'Buick' 'INFINITI' 'McLaren' 'Scion' 'Lamborghini' 'Bentley'
#  'Suzuki' 'Ferrari' 'Alfa' 'Rolls-Royce' 'Chrysler' 'Aston' 'Rivian'
#  'Lotus' 'Saturn' 'Lucid' 'Mercury' 'Maybach' 'FIAT' 'Plymouth' 'Bugatti']
# 53
# model:['F-150 Lariat' '335 i' 'XF Luxury' ... 'Q4 e-tron Sportback Premium'
#  'Countryman Cooper' 'S-10 LS']
# 1827
# model_year:[2018 2007 2009 2022 2001 2003 2014 2019 2016 2017 2013 2021 2015 2020
#  2012 2006 2023 2011 2010 1999 2004 1993 2002 2005 2008 1995 1998 2000
#  1997 1994 1996 2024 1992 1974]
# 34
# milage:[74349 80000 91491 ... 62850 82984 28750]
# 3212
# ...

# %%
from sklearn import preprocessing

# label_encoder object knows
# how to understand word labels.
label_encoder = preprocessing.LabelEncoder()

# Encode labels in column 'species'.
train['brand']= label_encoder.fit_transform(train['brand'])
train['model']= label_encoder.fit_transform(train['model'])
train['transmission']= label_encoder.fit_transform(train['transmission'])
train['engine']= label_encoder.fit_transform(train['engine'])
train['fuel_type']= label_encoder.fit_transform(train['fuel_type'])
train['ext_col']= label_encoder.fit_transform(train['ext_col'])
train['int_col']= label_encoder.fit_transform(train['int_col'])
train['accident']= label_encoder.fit_transform(train['accident'])
train['clean_title']= label_encoder.fit_transform(train['clean_title'])

# %%
len(train)
# Out:
# 54273

# %%
for col in train:
  print(f"{col}")
  print(len(train[col].unique()))
# Out:
# id
# 54273
# brand
# 53
# model
# 1827
# model_year
# 34
# milage
# 3212
# fuel_type
# 7
# engine
# 1061
# transmission
# 46
# ext_col
# 260
# int_col
# 124
# accident
# 2
# clean_title
# 1
# price
# 1481

# %%
col=["brand","model","model_year","milage","fuel_type","engine","transmission","ext_col","int_col","price"]
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
train[col]=scaler.fit_transform(train[col])

# %%
train
# Out:
#           id     brand     model  model_year    milage  fuel_type    engine  \
# 0          0  0.269231  0.352683        0.88  0.183376   0.333333  0.678302
# 1          1  0.076923  0.026835        0.66  0.197333   0.333333  0.503774
# 2          2  0.403846  0.969880        0.70  0.225713   0.333333  0.510377
# 3          3  0.076923  0.957284        0.96  0.005772   0.500000  0.609434
# 4          4  0.769231  0.379518        0.54  0.273895   0.333333  0.206604
# ...      ...       ...       ...         ...       ...        ...       ...
# 54268  54268  0.076923  0.955641        0.86  0.071376   0.333333  0.807547
# 54269  54269  0.057692  0.090361        0.82  0.233475   0.166667  0.250943
# 54270  54270  0.788462  0.230559        0.78  0.100985   0.333333  0.770755
# 54271  54271  0.788462  0.077766        0.98  0.003502   0.333333  0.718868
# 54272  54272  0.057692  0.096386        0.94  0.086194   0.500000  0.350943
#
# ...

# %%
train_x=train.drop("price",axis="columns")
train_y=train["price"]

# %%
train_x.drop("id",axis="columns")
# Out:
#           brand     model  model_year    milage  fuel_type    engine  \
# 0      0.269231  0.352683        0.88  0.183376   0.333333  0.678302
# 1      0.076923  0.026835        0.66  0.197333   0.333333  0.503774
# 2      0.403846  0.969880        0.70  0.225713   0.333333  0.510377
# 3      0.076923  0.957284        0.96  0.005772   0.500000  0.609434
# 4      0.769231  0.379518        0.54  0.273895   0.333333  0.206604
# ...         ...       ...         ...       ...        ...       ...
# 54268  0.076923  0.955641        0.86  0.071376   0.333333  0.807547
# 54269  0.057692  0.090361        0.82  0.233475   0.166667  0.250943
# 54270  0.788462  0.230559        0.78  0.100985   0.333333  0.770755
# 54271  0.788462  0.077766        0.98  0.003502   0.333333  0.718868
# 54272  0.057692  0.096386        0.94  0.086194   0.500000  0.350943
#
#        transmission   ext_col   int_col  accident  clean_title
# 0          0.044444  0.100386  0.463415         1            0
# ...

# %%
train_x.shape
# Out:
# (54273, 12)

# %%
import tensorflow as tp
from tensorflow import keras
model=keras.Sequential([
    keras .layers.Dense(25,input_shape=(12,),activation="relu"),
    keras .layers.Dense(25,activation="relu"),
    keras .layers.Dense(1)

])
model.compile(
    optimizer="adam",
    loss="mean_squared_error",
    metrics=[keras.metrics.RootMeanSquaredError()])

# %%
model.fit(train_x,train_y,epochs=50)
# Out:
# Epoch 1/50
# 1697/1697 [==============================] - 4s 2ms/step - loss: 19590.5254 - root_mean_squared_error: 139.9662
# Epoch 2/50
# 1697/1697 [==============================] - 3s 2ms/step - loss: 0.0178 - root_mean_squared_error: 0.1334
# Epoch 3/50
# 1697/1697 [==============================] - 3s 2ms/step - loss: 0.0171 - root_mean_squared_error: 0.1309
# Epoch 4/50
# 1697/1697 [==============================] - 3s 2ms/step - loss: 77.0725 - root_mean_squared_error: 8.7791
# Epoch 5/50
# 1697/1697 [==============================] - 5s 3ms/step - loss: 35.3239 - root_mean_squared_error: 5.9434
# Epoch 6/50
# 1697/1697 [==============================] - 4s 2ms/step - loss: 68.8766 - root_mean_squared_error: 8.2992
# Epoch 7/50
# 1697/1697 [==============================] - 3s 2ms/step - loss: 146.8071 - root_mean_squared_error: 12.1164
# Epoch 8/50
# 1697/1697 [==============================] - 3s 2ms/step - loss: 23.4706 - root_mean_squared_error: 4.8446
# Epoch 9/50
# ...

# %%
model.save("car_price.keras")

# %%
test['brand']= label_encoder.fit_transform(test['brand'])
test['model']= label_encoder.fit_transform(test['model'])
test['transmission']= label_encoder.fit_transform(test['transmission'])
test['engine']= label_encoder.fit_transform(test['engine'])
test['fuel_type']= label_encoder.fit_transform(test['fuel_type'])
test['ext_col']= label_encoder.fit_transform(test['ext_col'])
test['int_col']= label_encoder.fit_transform(test['int_col'])
test['accident']= label_encoder.fit_transform(test['accident'])
test['clean_title']= label_encoder.fit_transform(test['clean_title'])

# %%
test
# Out:
#           id  brand  model  model_year  milage  fuel_type  engine  \
# 0      54273     34    528        2014   73000          2     544
# 1      54274     26   1246        2015  128032          2     410
# 2      54275     34    317        2015   51983          2     311
# 3      54276     25   1318        2018   29500          2     911
# 4      54277      4   1710        2020   90000          2     633
# ...      ...    ...    ...         ...     ...        ...     ...
# 36178  90451     15   1763        2019    4500          2     807
# 36179  90452      9   1481        2004  185000          2     473
# 36180  90453     49    480        2011  116000          2      30
# 36181  90454     27   1082        2019   39000          2     843
# 36182  90455      9   1575        2012  162731          1     601
#
#        transmission  ext_col  int_col  accident  clean_title
# 0                33      220        8         1            0
# ...

# %%
col=["brand","model","model_year","milage","fuel_type","engine","transmission","ext_col","int_col"]
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
test[col]=scaler.fit_transform(test[col])

# %%
test
# Out:
#           id     brand     model  model_year    milage  fuel_type    engine  \
# 0      54273  0.653846  0.294972        0.80  0.180044   0.333333  0.524590
# 1      54274  0.500000  0.696089        0.82  0.315959   0.333333  0.395371
# 2      54275  0.653846  0.177095        0.82  0.128138   0.333333  0.299904
# 3      54276  0.480769  0.736313        0.88  0.072611   0.333333  0.878496
# 4      54277  0.076923  0.955307        0.92  0.222030   0.333333  0.610415
# ...      ...       ...       ...         ...       ...        ...       ...
# 36178  90451  0.288462  0.984916        0.90  0.010867   0.333333  0.778206
# 36179  90452  0.173077  0.827374        0.60  0.456656   0.333333  0.456123
# 36180  90453  0.942308  0.268156        0.74  0.286244   0.333333  0.028930
# 36181  90454  0.519231  0.604469        0.90  0.096073   0.333333  0.812922
# 36182  90455  0.173077  0.879888        0.76  0.401657   0.166667  0.579556
#
# ...

# %%
test.drop("id",axis="columns")
# Out:
#           brand     model  model_year    milage  fuel_type    engine  \
# 0      0.653846  0.294972        0.80  0.180044   0.333333  0.524590
# 1      0.500000  0.696089        0.82  0.315959   0.333333  0.395371
# 2      0.653846  0.177095        0.82  0.128138   0.333333  0.299904
# 3      0.480769  0.736313        0.88  0.072611   0.333333  0.878496
# 4      0.076923  0.955307        0.92  0.222030   0.333333  0.610415
# ...         ...       ...         ...       ...        ...       ...
# 36178  0.288462  0.984916        0.90  0.010867   0.333333  0.778206
# 36179  0.173077  0.827374        0.60  0.456656   0.333333  0.456123
# 36180  0.942308  0.268156        0.74  0.286244   0.333333  0.028930
# 36181  0.519231  0.604469        0.90  0.096073   0.333333  0.812922
# 36182  0.173077  0.879888        0.76  0.401657   0.166667  0.579556
#
#        transmission   ext_col   int_col  accident  clean_title
# 0          0.767442  0.960699  0.072727         1            0
# ...

# %%
predicted=model.predict(test)
# Out:
# 1131/1131 [==============================] - 2s 2ms/step

# %%
predicted
# Out:
# array([[-0.21400207],
#        [-0.21790832],
#        [-0.21742004],
#        ...,
#        [-0.3590216 ],
#        [-0.36536926],
#        [-0.3607306 ]], dtype=float32)

# %%
original_predictions = scaler.inverse_transform(predicted)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-73-819586862deb> in <cell line: 1>()
# ----> 1 original_predictions = scaler.inverse_transform(predicted)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_data.py in inverse_transform(self, X)
#     539         )
#     540
# --> 541         X -= self.min_
#     542         X /= self.scale_
#     543         return X
#
# ValueError: non-broadcastable output operand with shape (36183,1) doesn't match the broadcast shape (36183,9)
