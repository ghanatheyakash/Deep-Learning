# %%
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt
import numpy as np

# %%
(x_train,y_train),(x_test,y_test)=keras.datasets.fashion_mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 [==============================] - 1s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 [==============================] - 1s 0us/step

# %%
x_train=x_train/255
x_test=x_test/255

# %%
x_train.shape
# Out:
# (60000, 28, 28)

# %%
model=keras.Sequential([
    keras.layers.Flatten(input_shape=(28,28)),
    keras.layers.Dense(1000,activation="relu"),
    keras.layers.Dense(5000,activation="relu"),
    keras.layers.Dense(10,activation="sigmoid")
]
)
model.compile(
    optimizer="SGD",
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"]

)

# %%
model.fit(x_train,y_train,epochs=50)
# Out:
# Epoch 1/50
# 1875/1875 [==============================] - 13s 4ms/step - loss: 0.6805 - accuracy: 0.7801
# Epoch 2/50
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.4704 - accuracy: 0.8359
# Epoch 3/50
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.4268 - accuracy: 0.8520
# Epoch 4/50
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.4000 - accuracy: 0.8600
# Epoch 5/50
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3798 - accuracy: 0.8664
# Epoch 6/50
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.3631 - accuracy: 0.8716
# Epoch 7/50
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.3501 - accuracy: 0.8763
# Epoch 8/50
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.3373 - accuracy: 0.8814
# Epoch 9/50
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3278 - accuracy: 0.8841
# Epoch 10/50
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.3181 - accuracy: 0.8872
# Epoch 11/50
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3080 - accuracy: 0.8904
# Epoch 12/50
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.3005 - accuracy: 0.8927
# Epoch 13/50
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2921 - accuracy: 0.8961
# Epoch 14/50
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.2861 - accuracy: 0.8980
# Epoch 15/50
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.2784 - accuracy: 0.9000
# Epoch 16/50
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.2727 - accuracy: 0.9021
# Epoch 17/50
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2659 - accuracy: 0.9043
# Epoch 18/50
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.2592 - accuracy: 0.9075
# Epoch 19/50
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2550 - accuracy: 0.9082
# Epoch 20/50
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.2487 - accuracy: 0.9120
# Epoch 21/50
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2433 - accuracy: 0.9126
# Epoch 22/50
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.2380 - accuracy: 0.9146
# Epoch 23/50
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2340 - accuracy: 0.9159
# Epoch 24/50
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.2291 - accuracy: 0.9175
# Epoch 25/50
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2241 - accuracy: 0.9201
# Epoch 26/50
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.2196 - accuracy: 0.9215
# Epoch 27/50
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2147 - accuracy: 0.9229
# Epoch 28/50
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.2108 - accuracy: 0.9254
# Epoch 29/50
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.2071 - accuracy: 0.9258
# Epoch 30/50
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.2022 - accuracy: 0.9287
# Epoch 31/50
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.1990 - accuracy: 0.9297
# Epoch 32/50
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.1945 - accuracy: 0.9309
# Epoch 33/50
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.1907 - accuracy: 0.9323
# Epoch 34/50
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.1861 - accuracy: 0.9349
# Epoch 35/50
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.1833 - accuracy: 0.9355
# Epoch 36/50
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.1790 - accuracy: 0.9364
# Epoch 37/50
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.1744 - accuracy: 0.9392
# Epoch 38/50
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.1724 - accuracy: 0.9391
# Epoch 39/50
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.1687 - accuracy: 0.9407
# Epoch 40/50
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.1643 - accuracy: 0.9421
# Epoch 41/50
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.1616 - accuracy: 0.9434
# Epoch 42/50
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.1583 - accuracy: 0.9446
# Epoch 43/50
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.1550 - accuracy: 0.9450
# Epoch 44/50
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.1513 - accuracy: 0.9470
# Epoch 45/50
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.1487 - accuracy: 0.9478
# Epoch 46/50
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.1452 - accuracy: 0.9494
# Epoch 47/50
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.1422 - accuracy: 0.9509
# Epoch 48/50
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.1399 - accuracy: 0.9513
# Epoch 49/50
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.1359 - accuracy: 0.9525
# Epoch 50/50
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.1322 - accuracy: 0.9541

# %%
predict=model.predict(x_test)
# Out:
# 313/313 [==============================] - 1s 2ms/step

# %%
predict[4]
# Out:
# array([0.9993912 , 0.02979798, 0.9552597 , 0.7779461 , 0.9844087 ,
#        0.00103475, 0.99995255, 0.00130114, 0.11353683, 0.00250782],
#       dtype=float32)

# %%
img=x_test[4]*255
plt.imshow(img)

# %%
y_train=keras.utils.to_categorical(
    y_train,num_classes=10,dtype="float32"
)
y_test=keras.utils.to_categorical(
    y_test,num_classes=10,dtype="float32"
)

# %%
model1=keras.Sequential([
    keras.layers.Flatten(input_shape=(28,28)),
    keras.layers.Dense(1000,activation="relu"),
    keras.layers.Dense(5000,activation="relu"),
    keras.layers.Dense(10,activation="sigmoid")
]
)
model1.compile(
    optimizer="SGD",
    loss="categorical_crossentropy",
    metrics=["accuracy"]

)

# %%
model1.fit(x_train,y_train,epochs=10)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.6751 - accuracy: 0.7812
# Epoch 2/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.4686 - accuracy: 0.8374
# Epoch 3/10
# 1875/1875 [==============================] - 12s 6ms/step - loss: 0.4256 - accuracy: 0.8523
# Epoch 4/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.3979 - accuracy: 0.8614
# Epoch 5/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.3777 - accuracy: 0.8672
# Epoch 6/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.3627 - accuracy: 0.8724
# Epoch 7/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.3486 - accuracy: 0.8769
# Epoch 8/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.3367 - accuracy: 0.8803
# Epoch 9/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.3263 - accuracy: 0.8842
# Epoch 10/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.3170 - accuracy: 0.8874

# %%
model.predict(x_test)
# Out:
# 313/313 [==============================] - 1s 2ms/step
# array([[1.97144058e-02, 8.60702805e-03, 3.79931360e-01, ...,
#         9.94331121e-01, 5.12739480e-01, 9.99995112e-01],
#        [9.99173224e-01, 6.14174083e-03, 9.99999881e-01, ...,
#         1.01661826e-04, 3.21508497e-02, 7.06389255e-05],
#        [9.88569140e-01, 1.00000000e+00, 1.47643924e-01, ...,
#         3.12626897e-03, 6.30012751e-02, 7.75949884e-05],
#        ...,
#        [9.34622169e-01, 3.48557252e-04, 9.30230975e-01, ...,
#         9.10112336e-02, 9.99994636e-01, 6.34202588e-05],
#        [6.40364587e-01, 9.99999642e-01, 1.47789523e-01, ...,
#         5.22888312e-03, 2.12867595e-02, 6.37616739e-02],
#        [2.70258095e-02, 4.74389754e-02, 1.68410987e-01, ...,
#         9.77226019e-01, 6.26938701e-01, 1.12909153e-01]], dtype=float32)

# %%
predict[6]
# Out:
# array([6.7843542e-02, 2.0035040e-01, 9.8098582e-01, 8.4694350e-01,
#        9.9999845e-01, 1.3989674e-02, 9.9935442e-01, 2.7547209e-04,
#        2.7318963e-01, 3.0493637e-04], dtype=float32)

# %%
img=x_test[6]
plt.imshow(img)
